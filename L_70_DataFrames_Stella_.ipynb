# %% [markdown]
# <a href="https://colab.research.google.com/github/stmlufe/exercises/blob/master/L_70_DataFrames_Stella_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas
#
# Importe o pacote `pandas`. Chame-o de `pd`.

# %%
#Resposta
import pandas as pd

# %% [markdown]
# ## Milionários
#
# O link abaixo contém um csv com dados sobre milionários.
#
# 1. Importe o csv como um dataframe chamado `milionarios`. Quantas linhas e colunas tem esse dataframe?

# %%
url = 'https://corgis-edu.github.io/corgis/datasets/csv/billionaires/billionaires.csv'

# %%
#Resposta
milionarios = pd.read_csv('https://corgis-edu.github.io/corgis/datasets/csv/billionaires/billionaires.csv')
milionarios
# Out:
#                 name  rank  year  company.founded  \
# 0         Bill Gates     1  1996             1975
# 1         Bill Gates     1  2001             1975
# 2         Bill Gates     1  2014             1975
# 3     Warren Buffett     2  1996             1962
# 4     Warren Buffett     2  2001             1962
# ...              ...   ...   ...              ...
# 2609     Wu Chung-Yi  1565  2014             1991
# 2610        Wu Xiong  1565  2014             1999
# 2611       Yang Keng  1565  2014                0
# 2612   Zdenek Bakala  1565  2014             1994
# 2613     Zhu Wenchen  1565  2014             1999
#
#                          company.name company.relationship  \
# 0                           Microsoft              founder
# 1                           Microsoft              founder
# 2                           Microsoft              founder
# 3                  Berkshire Hathaway              founder
# 4                  Berkshire Hathaway              founder
# ...                               ...                  ...
# 2609                           Tingyi             investor
# 2610  Biostime International Holdings                owner
# 2611                    Blue Ray Corp             chairman
# 2612                   Patria Finance              founder
# 2613       Furen Pharmaceutical Group             chairman
#
#           company.sector company.type  demographics.age demographics.gender  \
# 0               Software          new                40                male
# 1               Software          new                45                male
# 2               Software          new                58                male
# 3                Finance          new                65                male
# 4                Finance          new                70                male
# ...                  ...          ...               ...                 ...
# 2609  beverages and food          new                55                male
# 2610      infant formula          new                 0                male
# 2611         real estate          new                53                male
# 2612                coal          new                53                male
# 2613     pharmaceuticals          new                48                male
#
#       ...  location.gdp location.region               wealth.type  \
# 0     ...  8.100000e+12   North America       founder non-finance
# 1     ...  1.060000e+13   North America       founder non-finance
# 2     ...  0.000000e+00   North America       founder non-finance
# 3     ...  8.100000e+12   North America       founder non-finance
# 4     ...  1.060000e+13   North America       founder non-finance
# ...   ...           ...             ...                       ...
# 2609  ...  0.000000e+00       East Asia                 executive
# 2610  ...  0.000000e+00       East Asia                 executive
# 2611  ...  0.000000e+00       East Asia         self-made finance
# 2612  ...  0.000000e+00          Europe  privatized and resources
# 2613  ...  0.000000e+00       East Asia                 executive
#
#      wealth.worth in billions wealth.how.category  wealth.how.from emerging  \
# 0                        18.5         New Sectors                      True
# 1                        58.7         New Sectors                      True
# 2                        76.0         New Sectors                      True
# 3                        15.0      Traded Sectors                      True
# 4                        32.3      Traded Sectors                      True
# ...                       ...                 ...                       ...
# 2609                      1.0      Traded Sectors                      True
# 2610                      1.0      Traded Sectors                      True
# 2611                      1.0           Financial                      True
# 2612                      1.0    Resource Related                      True
# 2613                      1.0         New Sectors                      True
#
#           wealth.how.industry  wealth.how.inherited wealth.how.was founder  \
# 0         Technology-Computer         not inherited                   True
# 1         Technology-Computer         not inherited                   True
# 2         Technology-Computer         not inherited                   True
# 3                    Consumer         not inherited                   True
# 4                    Consumer         not inherited                   True
# ...                       ...                   ...                    ...
# 2609  Non-consumer industrial         not inherited                   True
# 2610                 Consumer         not inherited                   True
# 2611              Real Estate         not inherited                   True
# 2612        Mining and metals         not inherited                   True
# 2613       Technology-Medical         not inherited                   True
#
#      wealth.how.was political
# 0                        True
# 1                        True
# 2                        True
# 3                        True
# 4                        True
# ...                       ...
# 2609                     True
# 2610                     True
# 2611                     True
# 2612                     True
# 2613                     True
#
# [2614 rows x 22 columns]

# %%
#Resposta
len(milionarios.index)
# Out:
# 2614

# %%
len(milionarios.columns)
# Out:
# 22

# %%
milionarios.columns
# Out:
# Index(['name', 'rank', 'year', 'company.founded', 'company.name',
#        'company.relationship', 'company.sector', 'company.type',
#        'demographics.age', 'demographics.gender', 'location.citizenship',
#        'location.country code', 'location.gdp', 'location.region',
#        'wealth.type', 'wealth.worth in billions', 'wealth.how.category',
#        'wealth.how.from emerging', 'wealth.how.industry',
#        'wealth.how.inherited', 'wealth.how.was founder',
#        'wealth.how.was political'],
#       dtype='object')

# %% [markdown]
# 2. Mostre seus primeiros 5 elementos.

# %%
#Resposta
milionarios.head(5)
# Out:
#              name  rank  year  company.founded        company.name  \
# 0      Bill Gates     1  1996             1975           Microsoft
# 1      Bill Gates     1  2001             1975           Microsoft
# 2      Bill Gates     1  2014             1975           Microsoft
# 3  Warren Buffett     2  1996             1962  Berkshire Hathaway
# 4  Warren Buffett     2  2001             1962  Berkshire Hathaway
#
#   company.relationship company.sector company.type  demographics.age  \
# 0              founder       Software          new                40
# 1              founder       Software          new                45
# 2              founder       Software          new                58
# 3              founder        Finance          new                65
# 4              founder        Finance          new                70
#
#   demographics.gender  ...  location.gdp location.region          wealth.type  \
# 0                male  ...  8.100000e+12   North America  founder non-finance
# 1                male  ...  1.060000e+13   North America  founder non-finance
# 2                male  ...  0.000000e+00   North America  founder non-finance
# 3                male  ...  8.100000e+12   North America  founder non-finance
# 4                male  ...  1.060000e+13   North America  founder non-finance
#
#   wealth.worth in billions wealth.how.category  wealth.how.from emerging  \
# 0                     18.5         New Sectors                      True
# 1                     58.7         New Sectors                      True
# 2                     76.0         New Sectors                      True
# 3                     15.0      Traded Sectors                      True
# 4                     32.3      Traded Sectors                      True
#
#    wealth.how.industry  wealth.how.inherited wealth.how.was founder  \
# 0  Technology-Computer         not inherited                   True
# 1  Technology-Computer         not inherited                   True
# 2  Technology-Computer         not inherited                   True
# 3             Consumer         not inherited                   True
# 4             Consumer         not inherited                   True
#
#   wealth.how.was political
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True
#
# [5 rows x 22 columns]

# %% [markdown]
# 2. Mostre 5 linhas aleatórias do dataframe

# %%
#Resposta
milionarios.sample(5)
# Out:
#                    name  rank  year  company.founded             company.name  \
# 1702         Ken Fisher   731  2014             1979       Fisher Investments
# 1786    Goh Cheng Liang   827  2014             1962                   Nipsea
# 317       Koo Cha-kyung   105  1996             1947                 LG Group
# 2244         Oleg Boyko  1270  2014             1995  Finstar Financial Group
# 163   Kyosuke Kinoshita    55  2001             1948                     Acom
#
#      company.relationship    company.sector   company.type  demographics.age  \
# 1702              founder  money management            new                63
# 1786             chairman             paint  joint venture                 0
# 317              relation       electronics            new                 0
# 2244              founder            retail            new                49
# 163              relation    consumer loans            new                60
#
#      demographics.gender  ...  location.gdp location.region  \
# 1702                male  ...  0.000000e+00   North America
# 1786                male  ...  0.000000e+00       East Asia
# 317                 male  ...  6.030000e+11       East Asia
# 2244                male  ...  0.000000e+00          Europe
# 163                 male  ...  4.160000e+12       East Asia
#
#               wealth.type wealth.worth in billions wealth.how.category  \
# 1702    self-made finance                      2.4           Financial
# 1786  founder non-finance                      2.2      Traded Sectors
# 317             inherited                      2.9           Financial
# 2244  founder non-finance                      1.4  Non-Traded Sectors
# 163             inherited                      5.6           Financial
#
#       wealth.how.from emerging    wealth.how.industry  wealth.how.inherited  \
# 1702                      True       Money Management         not inherited
# 1786                      True               Consumer         not inherited
# 317                       True  Diversified financial                father
# 2244                      True                  Media         not inherited
# 163                       True       Money Management                father
#
#      wealth.how.was founder wealth.how.was political
# 1702                   True                     True
# 1786                   True                     True
# 317                    True                     True
# 2244                   True                     True
# 163                    True                     True
#
# [5 rows x 22 columns]

# %% [markdown]
# 3. Mostre um dataframe contendo apenas os dados do Bill Gates.

# %%
milionarios = milionarios.set_index('name')
milionarios
# Out:
#                 rank  year  company.founded                     company.name  \
# name
# Bill Gates         1  1996             1975                        Microsoft
# Bill Gates         1  2001             1975                        Microsoft
# Bill Gates         1  2014             1975                        Microsoft
# Warren Buffett     2  1996             1962               Berkshire Hathaway
# Warren Buffett     2  2001             1962               Berkshire Hathaway
# ...              ...   ...              ...                              ...
# Wu Chung-Yi     1565  2014             1991                           Tingyi
# Wu Xiong        1565  2014             1999  Biostime International Holdings
# Yang Keng       1565  2014                0                    Blue Ray Corp
# Zdenek Bakala   1565  2014             1994                   Patria Finance
# Zhu Wenchen     1565  2014             1999       Furen Pharmaceutical Group
#
#                company.relationship      company.sector company.type  \
# name
# Bill Gates                  founder            Software          new
# Bill Gates                  founder            Software          new
# Bill Gates                  founder            Software          new
# Warren Buffett              founder             Finance          new
# Warren Buffett              founder             Finance          new
# ...                             ...                 ...          ...
# Wu Chung-Yi                investor  beverages and food          new
# Wu Xiong                      owner      infant formula          new
# Yang Keng                  chairman         real estate          new
# Zdenek Bakala               founder                coal          new
# Zhu Wenchen                chairman     pharmaceuticals          new
#
#                 demographics.age demographics.gender location.citizenship  \
# name
# Bill Gates                    40                male        United States
# Bill Gates                    45                male        United States
# Bill Gates                    58                male        United States
# Warren Buffett                65                male        United States
# Warren Buffett                70                male        United States
# ...                          ...                 ...                  ...
# Wu Chung-Yi                   55                male               Taiwan
# Wu Xiong                       0                male                China
# Yang Keng                     53                male                China
# Zdenek Bakala                 53                male       Czech Republic
# Zhu Wenchen                   48                male                China
#
#                 ...  location.gdp  location.region               wealth.type  \
# name            ...
# Bill Gates      ...  8.100000e+12    North America       founder non-finance
# Bill Gates      ...  1.060000e+13    North America       founder non-finance
# Bill Gates      ...  0.000000e+00    North America       founder non-finance
# Warren Buffett  ...  8.100000e+12    North America       founder non-finance
# Warren Buffett  ...  1.060000e+13    North America       founder non-finance
# ...             ...           ...              ...                       ...
# Wu Chung-Yi     ...  0.000000e+00        East Asia                 executive
# Wu Xiong        ...  0.000000e+00        East Asia                 executive
# Yang Keng       ...  0.000000e+00        East Asia         self-made finance
# Zdenek Bakala   ...  0.000000e+00           Europe  privatized and resources
# Zhu Wenchen     ...  0.000000e+00        East Asia                 executive
#
#                wealth.worth in billions  wealth.how.category  \
# name
# Bill Gates                         18.5          New Sectors
# Bill Gates                         58.7          New Sectors
# Bill Gates                         76.0          New Sectors
# Warren Buffett                     15.0       Traded Sectors
# Warren Buffett                     32.3       Traded Sectors
# ...                                 ...                  ...
# Wu Chung-Yi                         1.0       Traded Sectors
# Wu Xiong                            1.0       Traded Sectors
# Yang Keng                           1.0            Financial
# Zdenek Bakala                       1.0     Resource Related
# Zhu Wenchen                         1.0          New Sectors
#
#                wealth.how.from emerging      wealth.how.industry  \
# name
# Bill Gates                         True      Technology-Computer
# Bill Gates                         True      Technology-Computer
# Bill Gates                         True      Technology-Computer
# Warren Buffett                     True                 Consumer
# Warren Buffett                     True                 Consumer
# ...                                 ...                      ...
# Wu Chung-Yi                        True  Non-consumer industrial
# Wu Xiong                           True                 Consumer
# Yang Keng                          True              Real Estate
# Zdenek Bakala                      True        Mining and metals
# Zhu Wenchen                        True       Technology-Medical
#
#                wealth.how.inherited wealth.how.was founder  \
# name
# Bill Gates            not inherited                   True
# Bill Gates            not inherited                   True
# Bill Gates            not inherited                   True
# Warren Buffett        not inherited                   True
# Warren Buffett        not inherited                   True
# ...                             ...                    ...
# Wu Chung-Yi           not inherited                   True
# Wu Xiong              not inherited                   True
# Yang Keng             not inherited                   True
# Zdenek Bakala         not inherited                   True
# Zhu Wenchen           not inherited                   True
#
#                 wealth.how.was political
# name
# Bill Gates                          True
# Bill Gates                          True
# Bill Gates                          True
# Warren Buffett                      True
# Warren Buffett                      True
# ...                                  ...
# Wu Chung-Yi                         True
# Wu Xiong                            True
# Yang Keng                           True
# Zdenek Bakala                       True
# Zhu Wenchen                         True
#
# [2614 rows x 21 columns]

# %%
#Resposta
milionarios.loc['Bill Gates']
# Out:
#             rank  year  company.founded company.name company.relationship  \
# name
# Bill Gates     1  1996             1975    Microsoft              founder
# Bill Gates     1  2001             1975    Microsoft              founder
# Bill Gates     1  2014             1975    Microsoft              founder
#
#            company.sector company.type  demographics.age demographics.gender  \
# name
# Bill Gates       Software          new                40                male
# Bill Gates       Software          new                45                male
# Bill Gates       Software          new                58                male
#
#            location.citizenship  ...  location.gdp  location.region  \
# name                             ...
# Bill Gates        United States  ...  8.100000e+12    North America
# Bill Gates        United States  ...  1.060000e+13    North America
# Bill Gates        United States  ...  0.000000e+00    North America
#
#                     wealth.type wealth.worth in billions  wealth.how.category  \
# name
# Bill Gates  founder non-finance                     18.5          New Sectors
# Bill Gates  founder non-finance                     58.7          New Sectors
# Bill Gates  founder non-finance                     76.0          New Sectors
#
#            wealth.how.from emerging  wealth.how.industry wealth.how.inherited  \
# name
# Bill Gates                     True  Technology-Computer        not inherited
# Bill Gates                     True  Technology-Computer        not inherited
# Bill Gates                     True  Technology-Computer        not inherited
#
#            wealth.how.was founder  wealth.how.was political
# name
# Bill Gates                   True                      True
# Bill Gates                   True                      True
# Bill Gates                   True                      True
#
# [3 rows x 21 columns]

# %% [markdown]
# 4. Qual é o ano mais recente da base? Crie um dataframe chamado `milionarios_2014` onde você filtra apenas as linhas referentes àquele ano. Mostre as 5 primeiras linhas desse dataframe.
#
# Nós usaremos este dataframe daqui para frente.

# %%
milionarios.sort_values('year',ascending=False)
# Out:
#                             rank  year  company.founded          company.name  \
# name
# Maria-Elisabeth Schaeffler   430  2014             1946      Schaeffler Group
# Antonio Luiz Seabra          828  2014             1969     Natura Cosmeticos
# Stephen Bisciotti            796  2014             1983         Allegis Group
# Ted Turner                   796  2014             1970                   CNN
# Tor Peterson                 796  2014             1974      Glencore Xstrata
# ...                          ...   ...              ...                   ...
# Alfred von Oppenheim         190  1996             1789       ?Sal. Oppenheim
# Verspieren family            189  1996             1880            Verspieren
# Jacques Servier              188  1996             1954  Laboratories Servier
# Alain Wertheimer             187  1996             1909                Chanel
# Bill Gates                     1  1996             1975             Microsoft
#
#                            company.relationship    company.sector  \
# name
# Maria-Elisabeth Schaeffler             relation   roller bearings
# Antonio Luiz Seabra                     founder         cosmetics
# Stephen Bisciotti                       founder  staffing company
# Ted Turner                              founder             media
# Tor Peterson                           employee            mining
# ...                                         ...               ...
# Alfred von Oppenheim                   relation           banking
# Verspieren family                           NaN         insurance
# Jacques Servier                         founder   pharmaceuticals
# Alain Wertheimer                       relation      luxury goods
# Bill Gates                              founder          Software
#
#                            company.type  demographics.age demographics.gender  \
# name
# Maria-Elisabeth Schaeffler          new                72              female
# Antonio Luiz Seabra                 new                71                male
# Stephen Bisciotti                   new                53                male
# Ted Turner                      aquired                75                male
# Tor Peterson                        new                49                male
# ...                                 ...               ...                 ...
# Alfred von Oppenheim                new                 0                male
# Verspieren family                   new                 0                 NaN
# Jacques Servier                     new                 0                male
# Alain Wertheimer                    new                 0                male
# Bill Gates                          new                40                male
#
#                            location.citizenship  ...  location.gdp  \
# name                                             ...
# Maria-Elisabeth Schaeffler              Germany  ...  0.000000e+00
# Antonio Luiz Seabra                      Brazil  ...  0.000000e+00
# Stephen Bisciotti                 United States  ...  0.000000e+00
# Ted Turner                        United States  ...  0.000000e+00
# Tor Peterson                      United States  ...  0.000000e+00
# ...                                         ...  ...           ...
# Alfred von Oppenheim                    Germany  ...  2.500000e+12
# Verspieren family                        France  ...  1.610000e+12
# Jacques Servier                          France  ...  1.610000e+12
# Alain Wertheimer                         France  ...  1.610000e+12
# Bill Gates                        United States  ...  8.100000e+12
#
#                             location.region               wealth.type  \
# name
# Maria-Elisabeth Schaeffler           Europe                 inherited
# Antonio Luiz Seabra           Latin America       founder non-finance
# Stephen Bisciotti             North America       founder non-finance
# Ted Turner                    North America       founder non-finance
# Tor Peterson                  North America  privatized and resources
# ...                                     ...                       ...
# Alfred von Oppenheim                 Europe                 inherited
# Verspieren family                    Europe                 inherited
# Jacques Servier                      Europe         self-made finance
# Alain Wertheimer                     Europe                 inherited
# Bill Gates                    North America       founder non-finance
#
#                            wealth.worth in billions  wealth.how.category  \
# name
# Maria-Elisabeth Schaeffler                      3.6       Traded Sectors
# Antonio Luiz Seabra                             2.1       Traded Sectors
# Stephen Bisciotti                               2.2                    0
# Ted Turner                                      2.2   Non-Traded Sectors
# Tor Peterson                                    2.2     Resource Related
# ...                                             ...                  ...
# Alfred von Oppenheim                            2.0            Financial
# Verspieren family                               2.0       Traded Sectors
# Jacques Servier                                 2.0            Financial
# Alain Wertheimer                                2.0       Traded Sectors
# Bill Gates                                     18.5          New Sectors
#
#                            wealth.how.from emerging      wealth.how.industry  \
# name
# Maria-Elisabeth Schaeffler                     True  Non-consumer industrial
# Antonio Luiz Seabra                            True                 Consumer
# Stephen Bisciotti                              True                    Other
# Ted Turner                                     True                    Media
# Tor Peterson                                   True        Mining and metals
# ...                                             ...                      ...
# Alfred von Oppenheim                           True         Money Management
# Verspieren family                              True  Non-consumer industrial
# Jacques Servier                                True    Diversified financial
# Alain Wertheimer                               True                 Consumer
# Bill Gates                                     True      Technology-Computer
#
#                                 wealth.how.inherited wealth.how.was founder  \
# name
# Maria-Elisabeth Schaeffler              spouse/widow                   True
# Antonio Luiz Seabra                    not inherited                   True
# Stephen Bisciotti                      not inherited                   True
# Ted Turner                             not inherited                   True
# Tor Peterson                           not inherited                   True
# ...                                              ...                    ...
# Alfred von Oppenheim                  4th generation                   True
# Verspieren family           5th generation or longer                   True
# Jacques Servier                        not inherited                   True
# Alain Wertheimer                      3rd generation                   True
# Bill Gates                             not inherited                   True
#
#                             wealth.how.was political
# name
# Maria-Elisabeth Schaeffler                      True
# Antonio Luiz Seabra                             True
# Stephen Bisciotti                               True
# Ted Turner                                      True
# Tor Peterson                                    True
# ...                                              ...
# Alfred von Oppenheim                            True
# Verspieren family                               True
# Jacques Servier                                 True
# Alain Wertheimer                                True
# Bill Gates                                      True
#
# [2614 rows x 21 columns]

# %%
#Resposta
milionarios_2014 = milionarios[milionarios.year > 2013]
milionarios_2014
# Out:
#                   rank  year  company.founded  \
# name
# Bill Gates           1  2014             1975
# Carlos Slim Helu     2  2014             1990
# Amancio Ortega       3  2014             1975
# Warren Buffett       4  2014             1839
# Larry Ellison        5  2014             1977
# ...                ...   ...              ...
# Wu Chung-Yi       1565  2014             1991
# Wu Xiong          1565  2014             1999
# Yang Keng         1565  2014                0
# Zdenek Bakala     1565  2014             1994
# Zhu Wenchen       1565  2014             1999
#
#                                      company.name company.relationship  \
# name
# Bill Gates                              Microsoft              founder
# Carlos Slim Helu                           Telmex              founder
# Amancio Ortega                               Zara              founder
# Warren Buffett                 Berkshire Hathaway              founder
# Larry Ellison                              Oracle              founder
# ...                                           ...                  ...
# Wu Chung-Yi                                Tingyi             investor
# Wu Xiong          Biostime International Holdings                owner
# Yang Keng                           Blue Ray Corp             chairman
# Zdenek Bakala                      Patria Finance              founder
# Zhu Wenchen            Furen Pharmaceutical Group             chairman
#
#                       company.sector   company.type  demographics.age  \
# name
# Bill Gates                  Software            new                58
# Carlos Slim Helu      Communications  privatization                74
# Amancio Ortega               Fashion            new                77
# Warren Buffett               Finance        aquired                83
# Larry Ellison               software            new                69
# ...                              ...            ...               ...
# Wu Chung-Yi       beverages and food            new                55
# Wu Xiong              infant formula            new                 0
# Yang Keng                real estate            new                53
# Zdenek Bakala                   coal            new                53
# Zhu Wenchen          pharmaceuticals            new                48
#
#                  demographics.gender location.citizenship  ... location.gdp  \
# name                                                       ...
# Bill Gates                      male        United States  ...          0.0
# Carlos Slim Helu                male               Mexico  ...          0.0
# Amancio Ortega                  male                Spain  ...          0.0
# Warren Buffett                  male        United States  ...          0.0
# Larry Ellison                   male        United States  ...          0.0
# ...                              ...                  ...  ...          ...
# Wu Chung-Yi                     male               Taiwan  ...          0.0
# Wu Xiong                        male                China  ...          0.0
# Yang Keng                       male                China  ...          0.0
# Zdenek Bakala                   male       Czech Republic  ...          0.0
# Zhu Wenchen                     male                China  ...          0.0
#
#                   location.region               wealth.type  \
# name
# Bill Gates          North America       founder non-finance
# Carlos Slim Helu    Latin America  privatized and resources
# Amancio Ortega             Europe       founder non-finance
# Warren Buffett      North America       founder non-finance
# Larry Ellison       North America       founder non-finance
# ...                           ...                       ...
# Wu Chung-Yi             East Asia                 executive
# Wu Xiong                East Asia                 executive
# Yang Keng               East Asia         self-made finance
# Zdenek Bakala              Europe  privatized and resources
# Zhu Wenchen             East Asia                 executive
#
#                  wealth.worth in billions  wealth.how.category  \
# name
# Bill Gates                           76.0          New Sectors
# Carlos Slim Helu                     72.0   Non-Traded Sectors
# Amancio Ortega                       64.0   Non-Traded Sectors
# Warren Buffett                       58.2       Traded Sectors
# Larry Ellison                        48.0          New Sectors
# ...                                   ...                  ...
# Wu Chung-Yi                           1.0       Traded Sectors
# Wu Xiong                              1.0       Traded Sectors
# Yang Keng                             1.0            Financial
# Zdenek Bakala                         1.0     Resource Related
# Zhu Wenchen                           1.0          New Sectors
#
#                  wealth.how.from emerging      wealth.how.industry  \
# name
# Bill Gates                           True      Technology-Computer
# Carlos Slim Helu                     True                    Media
# Amancio Ortega                       True       Retail, Restaurant
# Warren Buffett                       True                 Consumer
# Larry Ellison                        True      Technology-Computer
# ...                                   ...                      ...
# Wu Chung-Yi                          True  Non-consumer industrial
# Wu Xiong                             True                 Consumer
# Yang Keng                            True              Real Estate
# Zdenek Bakala                        True        Mining and metals
# Zhu Wenchen                          True       Technology-Medical
#
#                  wealth.how.inherited wealth.how.was founder  \
# name
# Bill Gates              not inherited                   True
# Carlos Slim Helu        not inherited                   True
# Amancio Ortega          not inherited                   True
# Warren Buffett          not inherited                   True
# Larry Ellison           not inherited                   True
# ...                               ...                    ...
# Wu Chung-Yi             not inherited                   True
# Wu Xiong                not inherited                   True
# Yang Keng               not inherited                   True
# Zdenek Bakala           not inherited                   True
# Zhu Wenchen             not inherited                   True
#
#                   wealth.how.was political
# name
# Bill Gates                            True
# Carlos Slim Helu                      True
# Amancio Ortega                        True
# Warren Buffett                        True
# Larry Ellison                         True
# ...                                    ...
# Wu Chung-Yi                           True
# Wu Xiong                              True
# Yang Keng                             True
# Zdenek Bakala                         True
# Zhu Wenchen                           True
#
# [1653 rows x 21 columns]

# %%
#Resposta
milionarios_2014.head(5)
# Out:
#                   rank  year  company.founded        company.name  \
# name
# Bill Gates           1  2014             1975           Microsoft
# Carlos Slim Helu     2  2014             1990              Telmex
# Amancio Ortega       3  2014             1975                Zara
# Warren Buffett       4  2014             1839  Berkshire Hathaway
# Larry Ellison        5  2014             1977              Oracle
#
#                  company.relationship   company.sector   company.type  \
# name
# Bill Gates                    founder         Software            new
# Carlos Slim Helu              founder   Communications  privatization
# Amancio Ortega                founder          Fashion            new
# Warren Buffett                founder          Finance        aquired
# Larry Ellison                 founder         software            new
#
#                   demographics.age demographics.gender location.citizenship  \
# name
# Bill Gates                      58                male        United States
# Carlos Slim Helu                74                male               Mexico
# Amancio Ortega                  77                male                Spain
# Warren Buffett                  83                male        United States
# Larry Ellison                   69                male        United States
#
#                   ... location.gdp  location.region               wealth.type  \
# name              ...
# Bill Gates        ...          0.0    North America       founder non-finance
# Carlos Slim Helu  ...          0.0    Latin America  privatized and resources
# Amancio Ortega    ...          0.0           Europe       founder non-finance
# Warren Buffett    ...          0.0    North America       founder non-finance
# Larry Ellison     ...          0.0    North America       founder non-finance
#
#                  wealth.worth in billions  wealth.how.category  \
# name
# Bill Gates                           76.0          New Sectors
# Carlos Slim Helu                     72.0   Non-Traded Sectors
# Amancio Ortega                       64.0   Non-Traded Sectors
# Warren Buffett                       58.2       Traded Sectors
# Larry Ellison                        48.0          New Sectors
#
#                  wealth.how.from emerging  wealth.how.industry  \
# name
# Bill Gates                           True  Technology-Computer
# Carlos Slim Helu                     True                Media
# Amancio Ortega                       True   Retail, Restaurant
# Warren Buffett                       True             Consumer
# Larry Ellison                        True  Technology-Computer
#
#                  wealth.how.inherited wealth.how.was founder  \
# name
# Bill Gates              not inherited                   True
# Carlos Slim Helu        not inherited                   True
# Amancio Ortega          not inherited                   True
# Warren Buffett          not inherited                   True
# Larry Ellison           not inherited                   True
#
#                   wealth.how.was political
# name
# Bill Gates                            True
# Carlos Slim Helu                      True
# Amancio Ortega                        True
# Warren Buffett                        True
# Larry Ellison                         True
#
# [5 rows x 21 columns]

# %% [markdown]
# 5. A coluna `location.citizenship` identifica a cidadania do milionário. Liste os 5 países do mundo com mais milionários e o número de milionários em cada um desses países.

# %%
local = milionarios_2014.groupby('location.citizenship').sum().sort_values('wealth.worth in billions', ascending=False).head(5)

# %%
local = local.drop(columns = ['rank','year','company.founded','demographics.age','location.gdp'])

# %%
local
# Out:
#                       wealth.worth in billions  wealth.how.from emerging  \
# location.citizenship
# United States                           2322.4                       499
# Russia                                   422.5                       111
# Germany                                  401.4                        85
# China                                    375.8                       152
# France                                   235.3                        43
#
#                       wealth.how.was founder  wealth.how.was political
# location.citizenship
# United States                            499                       499
# Russia                                   111                       111
# Germany                                   85                        85
# China                                    152                       152
# France                                    43                        43

# %% [markdown]
# ## Covid
#
# Você já deve ter visto o [dashboard](https://coronavirus.jhu.edu/map.html) da universidade de John Hopkins mapeando o coronavirus. Os dados que eles utilizam estão [aqui](https://github.com/CSSEGISandData/COVID-19). Vamos pegar uma das bases de dados que eles utilizam. Esta:

# %%
link_covid = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'

# %% [markdown]
# 1. Importe a base de dados como um dataframe chamado `covid`

# %%
#Resposta
covid = pd.read_csv(link_covid)

# %% [markdown]
# 2. Mostre os primeiros 5 elementos desse dataframe

# %%
#Resposta
covid.head(5)
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/24/23  2/25/23  2/26/23  \
# 0        0        0        0        0  ...     7896     7896     7896
# 1        0        0        0        0  ...     3598     3598     3598
# 2        0        0        0        0  ...     6881     6881     6881
# 3        0        0        0        0  ...      165      165      165
# 4        0        0        0        0  ...     1931     1931     1931
#
#    2/27/23  2/28/23  3/1/23  3/2/23  3/3/23  3/4/23  3/5/23
# 0     7896     7896    7896    7896    7896    7896    7896
# 1     3598     3598    3598    3598    3598    3598    3598
# 2     6881     6881    6881    6881    6881    6881    6881
# 3      165      165     165     165     165     165     165
# 4     1933     1933    1933    1933    1933    1933    1933
#
# [5 rows x 1143 columns]

# %% [markdown]
# 3. Quantos casos o Brasil tinha no dia 7 de Setembro de 2020?
#
# Note que a base de dados é americana. Assim, Brasil se escreve "Brazil" e 7 de Setembro se escreve "9/7/20"

# %%
covid = covid.set_index('Country/Region')

# %%
#Resposta
covid.loc['Brazil','9/7/20']
# Out:
# 127070

# %% [markdown]
# ## Spotify
#
# O link a seguir tem uma base da Spotify com dados sobre músicas disponíveis nesse aplicativo.
#
# 1. Importe a base como um dataframe chamado `Spotify`. Mostre as 5 primeiras linhas.

# %%
url = 'https://corgis-edu.github.io/corgis/datasets/csv/music/music.csv'

# %%
#Resposta
spotify = pd.read_csv(url)

# %%
#Resposta
spotify.head(5)
# Out:
#    artist.familiarity  artist.hotttnesss           artist.id  artist.latitude  \
# 0            0.581794           0.401998  ARD7TVE1187B99BFB1          0.00000
# 1            0.630630           0.417500  ARMJAGH1187FB546F3         35.14968
# 2            0.487357           0.343428  ARKRRTF1187B9984DA          0.00000
# 3            0.630382           0.454231  AR7G5I41187FB4CE6C          0.00000
# 4            0.651046           0.401724  ARXR32B1187FB57099          0.00000
#
#    artist.location  artist.longitude       artist.name  artist.similar  \
# 0                0           0.00000            Casual             0.0
# 1                0         -90.04892      The Box Tops             0.0
# 2                0           0.00000  Sonora Santanera             0.0
# 3                0           0.00000          Adam Ant             0.0
# 4                0           0.00000               Gob             0.0
#
#      artist.terms  artist.terms_freq  ...  song.mode  song.mode_confidence  \
# 0         hip hop           1.000000  ...          0                 0.636
# 1  blue-eyed soul           1.000000  ...          0                 0.430
# 2           salsa           1.000000  ...          1                 0.565
# 3        pop rock           0.988584  ...          1                 0.749
# 4        pop punk           0.887288  ...          1                 0.371
#
#    song.start_of_fade_out  song.tatums_confidence  song.tatums_start  \
# 0                 218.932                   0.779            0.28519
# 1                 137.915                   0.969            0.20627
# 2                 172.304                   0.482            0.42132
# 3                 217.124                   0.601            0.56254
# 4                 198.699                   1.000            0.13576
#
#    song.tempo  song.time_signature  song.time_signature_confidence  \
# 0      92.198                  4.0                           0.778
# 1     121.274                  4.0                           0.384
# 2     100.070                  1.0                           0.000
# 3     119.293                  4.0                           0.000
# 4     129.738                  4.0                           0.562
#
#    song.title  song.year
# 0           0          0
# 1           0       1969
# 2           0          0
# 3           0       1982
# 4           0       2007
#
# [5 rows x 35 columns]

# %% [markdown]
# 2. Essa base tem quantas linhas e quantas colunas?

# %%
#Resposta
len(spotify.index)
# Out:
# 10000

# %%
len(spotify.columns)
# Out:
# 35

# %% [markdown]
# 3. Quais são as colunas dessa base?

# %%
#Resposta
spotify.columns
# Out:
# Index(['artist.familiarity', 'artist.hotttnesss', 'artist.id',
#        'artist.latitude', 'artist.location', 'artist.longitude', 'artist.name',
#        'artist.similar', 'artist.terms', 'artist.terms_freq', 'release.id',
#        'release.name', 'song.artist_mbtags', 'song.artist_mbtags_count',
#        'song.bars_confidence', 'song.bars_start', 'song.beats_confidence',
#        'song.beats_start', 'song.duration', 'song.end_of_fade_in',
#        'song.hotttnesss', 'song.id', 'song.key', 'song.key_confidence',
#        'song.loudness', 'song.mode', 'song.mode_confidence',
#        'song.start_of_fade_out', 'song.tatums_confidence', 'song.tatums_start',
#        'song.tempo', 'song.time_signature', 'song.time_signature_confidence',
#        'song.title', 'song.year'],
#       dtype='object')

# %% [markdown]
# 4. Cada linha corresponde a uma música e o identificador dessa música é a variável `song.id`. Transforme essa variável em um índice da base spotify.

# %%
#Resposta
song_ind = spotify.set_index('song.id')
song_ind
# Out:
#                     artist.familiarity  artist.hotttnesss           artist.id  \
# song.id
# SOMZWCG12A8C13C480            0.581794           0.401998  ARD7TVE1187B99BFB1
# SOCIWDW12A8C13D406            0.630630           0.417500  ARMJAGH1187FB546F3
# SOXVLOJ12AB0189215            0.487357           0.343428  ARKRRTF1187B9984DA
# SONHOTT12A8C13493C            0.630382           0.454231  AR7G5I41187FB4CE6C
# SOFSOCN12A8C143F5D            0.651046           0.401724  ARXR32B1187FB57099
# ...                                ...                ...                 ...
# SOLXXPY12A67ADABA0            0.722571           0.499826  AR4C6V01187FB3BAF4
# SOAYONI12A6D4F85C8            0.511663           0.409779  AR9JLBU1187B9AAEC4
# SOJZLAJ12AB017E8A2            0.433508           0.289903  ARS1DCR1187B9A4A56
# SORZSCJ12A8C132446            0.334457           0.216829  ARAGMIV11F4C843F78
# SOFAOMI12A6D4FA2D8            0.609182           0.509243  ARYXOV81187B99831D
#
#                     artist.latitude  artist.location  artist.longitude  \
# song.id
# SOMZWCG12A8C13C480          0.00000                0           0.00000
# SOCIWDW12A8C13D406         35.14968                0         -90.04892
# SOXVLOJ12AB0189215          0.00000                0           0.00000
# SONHOTT12A8C13493C          0.00000                0           0.00000
# SOFSOCN12A8C143F5D          0.00000                0           0.00000
# ...                             ...              ...               ...
# SOLXXPY12A67ADABA0         39.55792                0          -7.84481
# SOAYONI12A6D4F85C8        -33.96243                0          25.62326
# SOJZLAJ12AB017E8A2          0.00000                0           0.00000
# SORZSCJ12A8C132446          0.00000                0           0.00000
# SOFAOMI12A6D4FA2D8          0.00000                0           0.00000
#
#                                  artist.name  artist.similar  \
# song.id
# SOMZWCG12A8C13C480                    Casual             0.0
# SOCIWDW12A8C13D406              The Box Tops             0.0
# SOXVLOJ12AB0189215          Sonora Santanera             0.0
# SONHOTT12A8C13493C                  Adam Ant             0.0
# SOFSOCN12A8C143F5D                       Gob             0.0
# ...                                      ...             ...
# SOLXXPY12A67ADABA0                 Moonspell             0.0
# SOAYONI12A6D4F85C8            Danny Williams             0.0
# SOJZLAJ12AB017E8A2             Winston Reedy             0.0
# SORZSCJ12A8C132446  Myrick "Freeze" Guillory             0.0
# SOFAOMI12A6D4FA2D8       Seventh Day Slumber             0.0
#
#                           artist.terms  artist.terms_freq  ...  song.mode  \
# song.id                                                    ...
# SOMZWCG12A8C13C480             hip hop           1.000000  ...          0
# SOCIWDW12A8C13D406      blue-eyed soul           1.000000  ...          0
# SOXVLOJ12AB0189215               salsa           1.000000  ...          1
# SONHOTT12A8C13493C            pop rock           0.988584  ...          1
# SOFSOCN12A8C143F5D            pop punk           0.887288  ...          1
# ...                                ...                ...  ...        ...
# SOLXXPY12A67ADABA0  sympho black metal           0.999765  ...          1
# SOAYONI12A6D4F85C8              ballad           0.915417  ...          1
# SOJZLAJ12AB017E8A2         lovers rock           0.960115  ...          1
# SORZSCJ12A8C132446              zydeco           1.000000  ...          1
# SOFAOMI12A6D4FA2D8      christian rock           0.926220  ...          0
#
#                     song.mode_confidence  song.start_of_fade_out  \
# song.id
# SOMZWCG12A8C13C480                 0.636                 218.932
# SOCIWDW12A8C13D406                 0.430                 137.915
# SOXVLOJ12AB0189215                 0.565                 172.304
# SONHOTT12A8C13493C                 0.749                 217.124
# SOFSOCN12A8C143F5D                 0.371                 198.699
# ...                                  ...                     ...
# SOLXXPY12A67ADABA0                 0.540                 386.194
# SOAYONI12A6D4F85C8                 0.398                 163.463
# SOJZLAJ12AB017E8A2                 0.565                 186.015
# SORZSCJ12A8C132446                 0.503                 300.826
# SOFAOMI12A6D4FA2D8                 0.406                 193.167
#
#                     song.tatums_confidence  song.tatums_start  song.tempo  \
# song.id
# SOMZWCG12A8C13C480                   0.779            0.28519      92.198
# SOCIWDW12A8C13D406                   0.969            0.20627     121.274
# SOXVLOJ12AB0189215                   0.482            0.42132     100.070
# SONHOTT12A8C13493C                   0.601            0.56254     119.293
# SOFSOCN12A8C143F5D                   1.000            0.13576     129.738
# ...                                    ...                ...         ...
# SOLXXPY12A67ADABA0                   0.224            0.22262     140.185
# SOAYONI12A6D4F85C8                   0.604            0.07692      77.072
# SOJZLAJ12AB017E8A2                   1.000            0.27924     118.123
# SORZSCJ12A8C132446                   0.421            0.28192     137.663
# SOFAOMI12A6D4FA2D8                   0.710            0.20535     150.575
#
#                     song.time_signature  song.time_signature_confidence  \
# song.id
# SOMZWCG12A8C13C480                  4.0                           0.778
# SOCIWDW12A8C13D406                  4.0                           0.384
# SOXVLOJ12AB0189215                  1.0                           0.000
# SONHOTT12A8C13493C                  4.0                           0.000
# SOFSOCN12A8C143F5D                  4.0                           0.562
# ...                                 ...                             ...
# SOLXXPY12A67ADABA0                  4.0                           0.099
# SOAYONI12A6D4F85C8                  3.0                           0.597
# SOJZLAJ12AB017E8A2                  4.0                           0.205
# SORZSCJ12A8C132446                  4.0                           0.000
# SOFAOMI12A6D4FA2D8                  4.0                           0.317
#
#                     song.title  song.year
# song.id
# SOMZWCG12A8C13C480           0          0
# SOCIWDW12A8C13D406           0       1969
# SOXVLOJ12AB0189215           0          0
# SONHOTT12A8C13493C           0       1982
# SOFSOCN12A8C143F5D           0       2007
# ...                        ...        ...
# SOLXXPY12A67ADABA0           0       1998
# SOAYONI12A6D4F85C8           0       1998
# SOJZLAJ12AB017E8A2           0          0
# SORZSCJ12A8C132446           0          0
# SOFAOMI12A6D4FA2D8           0       2005
#
# [10000 rows x 34 columns]

# %%
song_ind.columns
# Out:
# Index(['artist.familiarity', 'artist.hotttnesss', 'artist.id',
#        'artist.latitude', 'artist.location', 'artist.longitude', 'artist.name',
#        'artist.similar', 'artist.terms', 'artist.terms_freq', 'release.id',
#        'release.name', 'song.artist_mbtags', 'song.artist_mbtags_count',
#        'song.bars_confidence', 'song.bars_start', 'song.beats_confidence',
#        'song.beats_start', 'song.duration', 'song.end_of_fade_in',
#        'song.hotttnesss', 'song.key', 'song.key_confidence', 'song.loudness',
#        'song.mode', 'song.mode_confidence', 'song.start_of_fade_out',
#        'song.tatums_confidence', 'song.tatums_start', 'song.tempo',
#        'song.time_signature', 'song.time_signature_confidence', 'song.title',
#        'song.year'],
#       dtype='object')

# %% [markdown]
# 5. Crie um dataframe contendo as seguintes colunas:
#     * O nome do artista (`artist.name`)
#     * O ano da música (`song.year`)
#
# Chame esse dataframe de `producao_do_artista`.

# %%
#Resposta
producao_do_artista = song_ind[['artist.name','song.year']]
producao_do_artista
# Out:
#                                  artist.name  song.year
# song.id
# SOMZWCG12A8C13C480                    Casual          0
# SOCIWDW12A8C13D406              The Box Tops       1969
# SOXVLOJ12AB0189215          Sonora Santanera          0
# SONHOTT12A8C13493C                  Adam Ant       1982
# SOFSOCN12A8C143F5D                       Gob       2007
# ...                                      ...        ...
# SOLXXPY12A67ADABA0                 Moonspell       1998
# SOAYONI12A6D4F85C8            Danny Williams       1998
# SOJZLAJ12AB017E8A2             Winston Reedy          0
# SORZSCJ12A8C132446  Myrick "Freeze" Guillory          0
# SOFAOMI12A6D4FA2D8       Seventh Day Slumber       2005
#
# [10000 rows x 2 columns]

# %% [markdown]
# 6. Quando o ano da autoria da música é desconhecido, ele aparece como zero. Crie um dataframe que contenha apenas as linhas onde o ano da música não é zero. Chame esse dataframe de `producao_do_artista`.

# %%
#Resposta
producao_do_artista = producao_do_artista[producao_do_artista['song.year'] != 0 ]

# %%
producao_do_artista.head(5)
# Out:
#                          artist.name  song.year
# song.id
# SOCIWDW12A8C13D406      The Box Tops       1969
# SONHOTT12A8C13493C          Adam Ant       1982
# SOFSOCN12A8C143F5D               Gob       2007
# SOIAZJW12AB01853F1  Planet P Project       1984
# SOBONFF12A6D4F84D8     Lionel Richie       1986

# %% [markdown]
# 7. Use o comando `.groupby` e `.count()` para contar quantas músicas foram compostas em cada ano. Salve isso no dataframe `musicas_por_ano`.

# %%
#Resposta
musicas_por_ano = producao_do_artista.groupby('song.year').count()

# %%
musicas_por_ano
# Out:
#            artist.name
# song.year
# 1926                 2
# 1927                 3
# 1929                 1
# 1930                 2
# 1934                 1
# ...                ...
# 2006               320
# 2007               285
# 2008               253
# 2009               250
# 2010                64
#
# [68 rows x 1 columns]

# %% [markdown]
# 8. Mude o nome da coluna de `musicas_por_ano` de `artist.name` para `numero_de_musicas`

# %%
#Resposta
musicas_por_ano.columns = ['numero_de_musicas']
musicas_por_ano
# Out:
#            numero_de_musicas
# song.year
# 1926                       2
# 1927                       3
# 1929                       1
# 1930                       2
# 1934                       1
# ...                      ...
# 2006                     320
# 2007                     285
# 2008                     253
# 2009                     250
# 2010                      64
#
# [68 rows x 1 columns]

# %% [markdown]
# Só de brincadeira, rode o comando abaixo e veja o que aparece:

# %%
musicas_por_ano.plot(figsize=(20,6),title='músicas por ano');
